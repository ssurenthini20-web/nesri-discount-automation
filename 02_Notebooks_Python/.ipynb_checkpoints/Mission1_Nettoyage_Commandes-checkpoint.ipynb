# %%
#Charger le fichier brut et créer la colonne numéro
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df_brut = pd.read_csv("/Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/01_Donnees_brutes/orders_export_1.csv")
print(f"Nombre de lignes brutes : {len(df_brut)}")
print(df_brut[["Name", "Total", "Financial Status", "Discount Code"]].head(10))
# Out:
# Nombre de lignes brutes : 58
#     Name   Total Financial Status Discount Code
# 0  #1057   52.60             paid           NaN
# 1  #1056  569.80             paid           NaN
# 2  #1055  206.36         refunded           NaN
# 3  #1054  690.80         refunded           NaN
# 4  #1053  200.33         refunded           NaN
# 5  #1052   62.90         refunded           NaN
# 6  #1051  114.00             paid       BONUS25
# 7  #1050  173.00             paid           NaN
# 8  #1049  243.40             paid           NaN
# 9  #1048  512.80             paid           NaN

# %%
#sélectionner les colonnes utiles
colonnes_utiles = ["Name", "Total", "Financial Status", "Created at", "Lineitem name", "Lineitem quantity", "Discount Code", "Refunded Amount"]
df_select = df_brut[colonnes_utiles].copy()
print(df_select.shape)
df_select.head()
# Out:
# (58, 8)
#     Name   Total Financial Status                 Created at  \
# 0  #1057   52.60             paid  2026-06-14 18:54:33 +0200
# 1  #1056  569.80             paid  2026-06-11 10:52:48 +0200
# 2  #1055  206.36         refunded  2026-06-10 09:37:31 +0200
# 3  #1054  690.80         refunded  2026-06-02 20:57:20 +0200
# 4  #1053  200.33         refunded  2026-06-01 11:13:46 +0200
#
#                                        Lineitem name  Lineitem quantity  \
# 0                       Grille-pain BOSCH TAT6A004EM                  1
# 1  Réfrigérateur TOP LOADED , Blanc, Compresseur ...                  1
# 2       Toaster 2 tranches Smeg TSF01UJEU-Union Jack                  1
# 3  Dometic CFX5 35 – Réfrigérateur portable à com...                  1
# 4   Annexe gonflable Dometic Ascension FTX TC Annexe                  1
#
#   Discount Code  Refunded Amount
# 0           NaN             0.00
# 1           NaN             0.00
# 2           NaN           206.36
# 3           NaN           690.80
# 4           NaN           200.33

# %%
# nettoyer la colonne de date et créer la colonne "Mois"
df_select["Created at"] = pd.to_datetime(df_select["Created at"], utc=True)
df_select["Mois"] = df_select["Created at"].dt.strftime("%Y-%m")
df_select[["Name", "Created at", "Mois"]].head()
# Out:
#     Name                Created at     Mois
# 0  #1057 2026-06-14 16:54:33+00:00  2026-06
# 1  #1056 2026-06-11 08:52:48+00:00  2026-06
# 2  #1055 2026-06-10 07:37:31+00:00  2026-06
# 3  #1054 2026-06-02 18:57:20+00:00  2026-06
# 4  #1053 2026-06-01 09:13:46+00:00  2026-06

# %%
#appliquer le filtre des commandes test (numéro < 1035)
df_select["Numero"] = df_select["Name"].str.replace("#", "").astype(int)

df_propre = df_select[df_select["Numero"] >= 1035].copy()

print(f"Lignes avant filtre : {len(df_select)}")
print(f"Lignes après filtre (commandes test retirées) : {len(df_propre)}")
print(f"Nombre de commandes test retirées : {len(df_select) - len(df_propre)}")
# Out:
# Lignes avant filtre : 58
# Lignes après filtre (commandes test retirées) : 23
# Nombre de commandes test retirées : 35

# %%
#simplifier les statuts de paiement
print(df_propre["Financial Status"].value_counts(dropna=False))
# Out:
# Financial Status
# paid                  13
# refunded               9
# partially_refunded     1
# Name: count, dtype: int64

# %%
#créer la colonne "Statut simplifié"
traduction_statut = {
    "paid": "Payee",
    "refunded": "Remboursee",
    "partially_refunded": "Partiellement remboursee"
}

df_propre["Statut simplifie"] = df_propre["Financial Status"].map(traduction_statut)

print(df_propre["Statut simplifie"].value_counts())
df_propre[["Name", "Total", "Financial Status", "Statut simplifie"]].head(10)
# Out:
# Statut simplifie
# Payee                       13
# Remboursee                   9
# Partiellement remboursee     1
# Name: count, dtype: int64
#     Name   Total Financial Status Statut simplifie
# 0  #1057   52.60             paid            Payee
# 1  #1056  569.80             paid            Payee
# 2  #1055  206.36         refunded       Remboursee
# 3  #1054  690.80         refunded       Remboursee
# 4  #1053  200.33         refunded       Remboursee
# 5  #1052   62.90         refunded       Remboursee
# 6  #1051  114.00             paid            Payee
# 7  #1050  173.00             paid            Payee
# 8  #1049  243.40             paid            Payee
# 9  #1048  512.80             paid            Payee

# %%
# sélectionner les colonnes finales et sauvegarder le fichier propre
df_final = df_propre[["Name", "Total", "Statut simplifie", "Mois", "Lineitem name", "Lineitem quantity", "Created at", "Refunded Amount"]].copy()
df_final = df_final.rename(columns={"Lineitem name": "Produit", "Lineitem quantity": "Quantite"})
print(df_final.shape)
df_final.head()
# Out:
# (23, 8)
#     Name   Total Statut simplifie     Mois  \
# 0  #1057   52.60            Payee  2026-06
# 1  #1056  569.80            Payee  2026-06
# 2  #1055  206.36       Remboursee  2026-06
# 3  #1054  690.80       Remboursee  2026-06
# 4  #1053  200.33       Remboursee  2026-06
#
#                                              Produit  Quantite  \
# 0                       Grille-pain BOSCH TAT6A004EM         1
# 1  Réfrigérateur TOP LOADED , Blanc, Compresseur ...         1
# 2       Toaster 2 tranches Smeg TSF01UJEU-Union Jack         1
# 3  Dometic CFX5 35 – Réfrigérateur portable à com...         1
# 4   Annexe gonflable Dometic Ascension FTX TC Annexe         1
#
#                  Created at  Refunded Amount
# 0 2026-06-14 16:54:33+00:00             0.00
# 1 2026-06-11 08:52:48+00:00             0.00
# 2 2026-06-10 07:37:31+00:00           206.36
# 3 2026-06-02 18:57:20+00:00           690.80
# 4 2026-06-01 09:13:46+00:00           200.33

# %%
print("Colonnes de df_select :", df_select.columns.tolist())
print()
print("Colonnes de df_propre :", df_propre.columns.tolist())
# Out:
# Colonnes de df_select : ['Name', 'Total', 'Financial Status', 'Created at', 'Lineitem name', 'Lineitem quantity', 'Discount Code', 'Refunded Amount', 'Mois', 'Numero']
#
# Colonnes de df_propre : ['Name', 'Total', 'Financial Status', 'Created at', 'Lineitem name', 'Lineitem quantity', 'Discount Code', 'Refunded Amount', 'Mois', 'Numero', 'Statut simplifie']

# %%
verif = df_brut[df_brut["Name"].isin(df_propre["Name"])][["Name", "Total", "Financial Status", "Refunded Amount"]]
print(verif.to_string(index=False))
# Out:
#  Name   Total   Financial Status  Refunded Amount
# #1057   52.60               paid             0.00
# #1056  569.80               paid             0.00
# #1055  206.36           refunded           206.36
# #1054  690.80           refunded           690.80
# #1053  200.33           refunded           200.33
# #1052   62.90           refunded            62.90
# #1051  114.00               paid             0.00
# #1050  173.00               paid             0.00
# #1049  243.40               paid             0.00
# #1048  512.80               paid             0.00
# #1047  174.00               paid             0.00
# #1046   91.36               paid             0.00
# #1045  560.00               paid             0.00
# #1044 1071.90           refunded          1071.90
# #1043  405.40           refunded           405.40
# #1042  260.40               paid             0.00
# #1041 1369.00           refunded          1369.00
# #1040  316.80           refunded           316.80
# #1039   58.60               paid             0.00
# #1038  217.33               paid             0.00
# #1037   96.60 partially_refunded            96.00
# #1036  690.80           refunded           690.80
# #1035  418.80               paid             0.00

# %%
colonnes_utiles = ["Name", "Total", "Financial Status", "Created at", "Lineitem name", "Lineitem quantity", "Discount Code", "Refunded Amount"]
df_select = df_brut[colonnes_utiles].copy()
print(df_select.shape)
df_select.head()
# Out:
# (58, 8)
#     Name   Total Financial Status                 Created at  \
# 0  #1057   52.60             paid  2026-06-14 18:54:33 +0200
# 1  #1056  569.80             paid  2026-06-11 10:52:48 +0200
# 2  #1055  206.36         refunded  2026-06-10 09:37:31 +0200
# 3  #1054  690.80         refunded  2026-06-02 20:57:20 +0200
# 4  #1053  200.33         refunded  2026-06-01 11:13:46 +0200
#
#                                        Lineitem name  Lineitem quantity  \
# 0                       Grille-pain BOSCH TAT6A004EM                  1
# 1  Réfrigérateur TOP LOADED , Blanc, Compresseur ...                  1
# 2       Toaster 2 tranches Smeg TSF01UJEU-Union Jack                  1
# 3  Dometic CFX5 35 – Réfrigérateur portable à com...                  1
# 4   Annexe gonflable Dometic Ascension FTX TC Annexe                  1
#
#   Discount Code  Refunded Amount
# 0           NaN             0.00
# 1           NaN             0.00
# 2           NaN           206.36
# 3           NaN           690.80
# 4           NaN           200.33

# %%
df_final["Created at"] = df_final["Created at"].dt.tz_localize(None)

chemin_sortie = "/Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/03_Donnees_propres/commandes_propres_v3.xlsx"
df_final.to_excel(chemin_sortie, index=False)
print(f"Fichier sauvegardé : {chemin_sortie}")
print(f"Nombre de lignes sauvegardées : {len(df_final)}")
# Out:
# Fichier sauvegardé : /Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/03_Donnees_propres/commandes_propres_v3.xlsx
# Nombre de lignes sauvegardées : 23

# %%
chemin_sortie = "/Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/03_Donnees_propres/commandes_propres_v3.xlsx"
df_final.to_excel(chemin_sortie, index=False)
print(f"Fichier sauvegardé : {chemin_sortie}")
print(f"Nombre de lignes sauvegardées : {len(df_final)}")
# Out:
# Fichier sauvegardé : /Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/03_Donnees_propres/commandes_propres_v3.xlsx
# Nombre de lignes sauvegardées : 23

# %%
verif_finale = pd.read_excel("/Users/surenthinisivakumar/Documents/Stage_Nesri_Discount/03_Donnees_propres/commandes_propres_v3.xlsx")
print(verif_finale.columns.tolist())
print()
print(verif_finale.head())
# Out:
# ['Name', 'Total', 'Statut simplifie', 'Mois', 'Produit', 'Quantite', 'Created at', 'Refunded Amount']
#
#     Name   Total Statut simplifie     Mois  \
# 0  #1057   52.60            Payee  2026-06
# 1  #1056  569.80            Payee  2026-06
# 2  #1055  206.36       Remboursee  2026-06
# 3  #1054  690.80       Remboursee  2026-06
# 4  #1053  200.33       Remboursee  2026-06
#
#                                              Produit  Quantite  \
# 0                       Grille-pain BOSCH TAT6A004EM         1
# 1  Réfrigérateur TOP LOADED , Blanc, Compresseur ...         1
# 2       Toaster 2 tranches Smeg TSF01UJEU-Union Jack         1
# 3  Dometic CFX5 35 – Réfrigérateur portable à com...         1
# 4   Annexe gonflable Dometic Ascension FTX TC Annexe         1
#
#            Created at  Refunded Amount
# 0 2026-06-14 16:54:33             0.00
# 1 2026-06-11 08:52:48             0.00
# 2 2026-06-10 07:37:31           206.36
# 3 2026-06-02 18:57:20           690.80
# 4 2026-06-01 09:13:46           200.33
